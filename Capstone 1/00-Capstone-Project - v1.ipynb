# %% [markdown]
# # Project Overview
#
# Determine if Fandango's 2015 ratings had a bias towards rating movies better to sell more tickets.
#
#
# ## Part One: Understanding the Background and Data

# %% [markdown]
# ### The Data
#
# Link to original article: [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/)
#
# Data openly available on fivethirtyeight's github: https://github.com/fivethirtyeight/data.
#
# Data contains two csv files as described below:
#
# #### all_sites_scores.csv

# %% [markdown]
# `all_sites_scores.csv` contains every film that has a Rotten Tomatoes rating, an RT User rating, a Metacritic score, a Metacritic User score, and IMDb score, and at least 30 fan reviews on Fandango. The data from Fandango was pulled on Aug. 24, 2015.

# %% [markdown]
# Column | Definition
# --- | -----------
# FILM | The film in question
# RottenTomatoes | The Rotten Tomatoes Tomatometer score  for the film
# RottenTomatoes_User | The Rotten Tomatoes user score for the film
# Metacritic | The Metacritic critic score for the film
# Metacritic_User | The Metacritic user score for the film
# IMDB | The IMDb user score for the film
# Metacritic_user_vote_count | The number of user votes the film had on Metacritic
# IMDB_user_vote_count | The number of user votes the film had on IMDb

# %% [markdown]
# #### fandango_scape.csv

# %% [markdown]
# `fandango_scrape.csv` contains every film 538 pulled from Fandango.
#
# Column | Definiton
# --- | ---------
# FILM | The movie
# STARS | Number of stars presented on Fandango.com
# RATING |  The Fandango ratingValue for the film, as pulled from the HTML of each page. This is the actual average score the movie obtained.
# VOTES | number of people who had reviewed the film at the time we pulled it.

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part Two: Exploring Fandango Displayed Scores versus True User Ratings

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# **Scatterplot showing the relationship between rating and votes**

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=fandango, x='RATING', y='VOTES')
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='VOTES'>

# %% [markdown]
# **Correlation between the columns:**

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
# create a function and use the apply method to strip out the years from the title of each movie and create a new column
# in the dataframe to store this information
def grab_year(string):
    return string[-5:-1]

fandango['YEAR'] = fandango['FILM'].apply(grab_year)

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %% [markdown]
# **How many movies are in the Fandango DataFrame per year?**

# %%
fandango['YEAR'].value_counts()
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: YEAR, dtype: int64

# %% [markdown]
# **Visualize the count of movies per year with a count plot:**

# %%
sns.countplot(data=fandango, x='YEAR')
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **10 movies with the highest number of votes?**

# %%
fandango.nlargest(10, columns='VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# **Number of movies that have zero votes?**

# %%
len(fandango[fandango['VOTES'] == 0])
# Out:
# 69

# %% [markdown]
# **Create a DataFrame of only reviewed films by removing any films that have zero votes.**

# %%
fandango_withreviews = fandango[fandango['VOTES'] != 0]

# %%
# confirm there are no movies with 0 votes in the new DataFrame
len(fandango_withreviews[fandango_withreviews['VOTES'] == 0])
# Out:
# 0

# %% [markdown]
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different than the rating shown to a user. Visualize this difference in distributions with a KDE plot.**

# %%
plt.figure(figsize=(9, 4))
sns.kdeplot(data=fandango_withreviews['RATING'], clip=(0, 5), shade=True, label='True Rating')
sns.kdeplot(data=fandango_withreviews['STARS'], clip=(0, 5), shade=True, label='Stars Displayed')

plt.legend(loc=(1.05, 0.5))
plt.show()

# %% [markdown]
# **To quantify this discrepancy, create new column of the difference between STARS displayed versus true RATING. Calculate this difference with STARS - RATING and round these differences to the nearest decimal point.**

# %%
fandango_withreviews['STARS_DIFF'] = round(fandango_withreviews['STARS'] - fandango_withreviews['RATING'], 1)
# Out:
# C:\Users\webst\AppData\Local\Temp\ipykernel_14820\2076929239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fandango_withreviews['STARS_DIFF'] = round(fandango_withreviews['STARS'] - fandango_withreviews['RATING'], 1)

# %%
fandango_withreviews
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %% [markdown]
# **Display a count plot to display the number of times a difference between STARS and RATING occurs:**

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=fandango_withreviews, x='STARS_DIFF', palette="rocket")
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %% [markdown]
# **Display the movie that had a 1 star differential**

# %%
fandango_withreviews[fandango_withreviews['STARS_DIFF'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ## Part Three: Comparison of Fandango Ratings to Other Sites
#
# Now compare the scores from Fandango to other movies sites.
#
# **Read in the "all_sites_scores.csv"**

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %% [markdown]
# **Initial data exploration**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %% [markdown]
# ### Rotten Tomatoes
#
# First taking a look at Rotten Tomatoes. RT has two sets of reviews, their critics reviews (ratings published by official critics) and user reviews.
#
# **Create a scatterplot exploring the relationship between RT Critic reviews and RT User reviews.**

# %%
plt.figure(figsize=(11, 4))
sns.scatterplot(data=all_sites, x='RottenTomatoes', y='RottenTomatoes_User')
plt.xlim(0, 100)
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# Quantify this difference by comparing the critics ratings and the RT User ratings.
#
# Calculate this with RottenTomatoes - RottenTomatoes_User.
#
# Note: Rotten_Diff here is Critics - User Score. So values closer to 0 means agreement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.
#
# **Create a new column based off the difference between critics ratings and users ratings for Rotten Tomatoes.**

# %%
all_sites['Rotten_Diff'] = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %% [markdown]
# **Calculate the Mean Absolute Difference between RT scores and RT User scores.**

# %%
all_sites['Rotten_Diff'].abs().mean()
# Out:
# 15.095890410958905

# %% [markdown]
# **Plot the distribution of the differences between RT Critics Score and RT User Score.**

# %%
plt.figure(figsize=(12, 4))
sns.histplot(data=all_sites, x='Rotten_Diff', kde=True, bins=25)
plt.title('RT Critics Score minus RT User Score')
plt.show()

# %% [markdown]
# **Create a distribution showing the *absolute value* difference between Critics and Users on Rotten Tomatoes.**

# %%
plt.figure(figsize=(12, 4))
sns.histplot(data=all_sites, x=all_sites['Rotten_Diff'].abs(), kde=True, bins=25)
plt.title('Abs Difference between RT Critics Score and RT User Score')
plt.show()

# %% [markdown]
# **Let's find out which movies are causing the largest differences. First, show the top 5 movies with the largest *negative* difference between Users and RT critics. Since we calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %% [markdown]
# **Display the top 5 movies where the users rated higher than critics on average:**

# %%
all_sites[['FILM', 'Rotten_Diff']].nsmallest(5, columns='Rotten_Diff')
# Out:
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **Show the top 5 movies critics scores higher than users on average.**

# %%
all_sites[['FILM', 'Rotten_Diff']].nlargest(5, columns='Rotten_Diff')
# Out:
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## MetaCritic
#
# Next looking at the ratings from MetaCritic. Metacritic also shows an average user rating versus their official displayed rating.

# %% [markdown]
# **Display a scatterplot of the Metacritic Rating versus the Metacritic User rating.**

# %%
plt.figure(figsize=(10, 4))
sns.scatterplot(data=all_sites, x='Metacritic', y='Metacritic_User')
plt.xlim(0, 100)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ## IMDB
#
# Lastly, exploring IMDB. Notice that both Metacritic and IMDB report back vote counts allowing us to analyze the most popular movies.
#
# **Create a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB.**

# %%
plt.figure(figsize=(10, 4))
sns.scatterplot(data=all_sites, x='Metacritic_user_vote_count', y='IMDB_user_vote_count')
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# **Notice there are two outliers here. The movie with the highest vote count on IMDB only has about 500 Metacritic ratings.**
#
# **Display the movie with the highest IMDB user vote count**

# %%
all_sites.nlargest(1, columns='IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **Display the movie with the highest Metacritic user vote count**

# %%
all_sites.nlargest(1, columns='Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ## Fandango Scores vs. All Sites
#
# Explore whether or not Fandango artificially displays higher ratings than warranted to boost ticket sales.

# %% [markdown]
# **Combine the Fandango Table with the All Sites table. Not every movie in the Fandango table is in the All Sites table, since some Fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so merge together both DataFrames based on the FILM columns.**

# %%
combined_df = pd.merge(left=fandango, right=all_sites, how='inner')
combined_df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %% [markdown]
# ### Normalize columns to Fandango STARS and RATINGS 0-5
#
# Notice that RT, Metacritic, and IMDB don't use a score between 0-5 stars like Fandango does. We need to normalize these values so they all fall between 0-5 stars so the relationship between reviews stays the same.
#
# **Create new normalized columns for all ratings so they match up within the 0-5 star range shown on Fandango.**

# %%
combined_df['RT_Norm'] = round(combined_df['RottenTomatoes'] / 20, 1)

# %%
combined_df['RTU_Norm'] = round(combined_df['RottenTomatoes_User'] / 20, 1)

# %%
combined_df['Meta_Norm'] = round(combined_df['Metacritic'] / 20, 1)

# %%
combined_df['Meta_U_Norm'] = round(combined_df['Metacritic_User'] / 2, 1)

# %%
combined_df['IMDB_Norm'] = round(combined_df['IMDB'] / 2, 1)

# %%
combined_df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      1.2
# ...

# %% [markdown]
# **Create a norm_scores DataFrame that only contains the normalizes ratings. Include both STARS and RATING from the original Fandango table.**

# %%
norm_scores = combined_df[['STARS', 'RATING', 'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3          1.6        2.1
# 1    4.5     4.5      3.6       4.0        3.0          3.5        3.6
# 2    5.0     4.8      3.6       4.2        3.6          3.3        3.7
# 3    5.0     4.8      4.0       4.2        3.4          3.4        3.7
# 4    4.5     4.5      4.9       4.5        4.7          4.4        4.3

# %% [markdown]
# ### Comparing Distribution of Scores Across Sites
#
#
# Does Fandango display abnormally high ratings? We already know it pushs displayed RATING higher than STARS, but are the ratings themselves higher than average?
#
#
# **Display a plot comparing the distributions of normalized ratings across all sites. There are many ways to do this, but explore the Seaborn KDEplot docs for some simple ways to quickly show this. Don't worry if your plot format does not look exactly the same as ours, as long as the differences in distribution are clear.**
#
# Reference for move_legend function used below: https://github.com/mwaskom/seaborn/issues/2280

# %%
# Function from the link above
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.kdeplot(data=norm_scores, clip=(0, 5), shade=True, palette='Set1')

move_legend(ax, "upper left")

# %% [markdown]
# **Fandango can be seen to have an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**
#
# **Create a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango.**

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.kdeplot(data=norm_scores[['RT_Norm', 'STARS']], clip=(0, 5), shade=True, palette='Set1')

move_legend(ax, "upper left")

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=norm_scores['STARS'], clip=(0, 5), shade=True, label='STARS')
sns.kdeplot(data=norm_scores['RT_Norm'], clip=(0, 5), shade=True, label='RT_Norm')

plt.legend(loc=2)
plt.show()

# %% [markdown]
# **Create a histplot comparing all normalized scores.**

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=norm_scores, bins=50)
plt.show()

# %% [markdown]
# ### How are the worst movies rated across all platforms?
#
# **Create a clustermap visualization of all normalized scores. Note the differences in ratings, highly rated movies should be clustered together versus poorly rated movies.**

# %%
sns.clustermap(data=norm_scores, cmap='magma', col_cluster=False)
plt.show()

# %% [markdown]
# **Clearly, Fandango is rating movies much higher than other sites, especially considering that it is then displaying a rounded up version of the rating. Let's examine the top 10 worst movies. Based off the Rotten Tomatoes Critic Ratings, what are the top 10 lowest rated movies? What are the normalized scores across all platforms for these movies?**

# %%
# Add in FILM column to the norm_scores DataFrame
norm_scores['FILM'] = combined_df['FILM']
# Out:
# C:\Users\webst\AppData\Local\Temp\ipykernel_6564\225885148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norm_scores['FILM'] = combined_df['FILM']

# %%
norm_scores.nsmallest(10, columns='RT_Norm')
# Out:
#     STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 49    3.5     3.5      0.2       1.8        0.6          1.2        2.2
# 25    4.5     4.1      0.4       2.3        1.3          2.3        3.0
# 28    3.0     2.7      0.4       1.0        1.4          1.2        2.0
# 54    4.0     3.7      0.4       1.8        1.6          1.8        2.4
# 84    4.0     3.9      0.4       2.4        1.4          1.6        3.0
# 50    4.0     3.6      0.5       1.8        1.5          2.8        2.3
# 77    3.5     3.2      0.6       1.8        1.5          2.0        2.8
# 78    3.5     3.2      0.6       1.5        1.4          1.6        2.8
# 83    3.5     3.3      0.6       1.7        1.6          2.5        2.8
# 87    3.5     3.2      0.6       1.4        1.6          1.9        2.7
#
#                              FILM
# 49  Paul Blart: Mall Cop 2 (2015)
# 25                 Taken 3 (2015)
# 28          Fantastic Four (2015)
# 54             Hot Pursuit (2015)
# ...

# %% [markdown]
# **Lastly, visualize the distribution of ratings across all sites for the top 10 worst movies.**

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=norm_scores.nsmallest(10, columns='RT_Norm'), shade=True, clip=(0, 5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# **Looking at the distributions above, it can be seen that the Fandango STARS and RATINGS have distributions between 2 and 5, with most of the data landing roughly around a rating of 3.5. When comparing to the distributions from the other sites, these are much higher and there does not appear to be any badly rated movies on Fandango.**
